# %% [markdown]
# <a href="https://colab.research.google.com/github/toshkar/SBER-model/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 2 - 38:00 - доступ ко всем его colab файлам находится на гитхабе WISEPLAT/_NN
# модель не учитывает сплиты и дивиденды
# (с) модель обучается на 85% предыдущих данных до 2018 года, а тестирует их на 15% последних данных
# нормализация простая и взята из первоначального англоязычного файла 24:00 - в окне обучения все цены делятся на первую цену за вычетом единички, а он хочет сделать по изменению процентов (процентное изменение по цене)

# %%
# активация TensorBoard
# Load the Tensorboard notebook extension
# %load_ext tensorboard
# Clear any logs from previous runs
# !rm -rf ./logs/
# Log dir for TensorBoard
from datetime import datetime
log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")

# %%
# импортируем необходимые библиотеки
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt # чтобы рисовать из matplotlib

import pandas as pd

# %%
from keras.models import Model #basic class for specifying and training a neural network
from keras.layers import Input, Dense, LSTM, Dropout
from tensorflow.keras.layers import BatchNormalization #from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# daily price from github
# эта часть используется для загрузки из csv, если не настроен онлайн вывод. Его настройку объясняет в предыдущих видео с помощью баз данных
filename = ('https://raw.githubusercontent.com/WISEPLAT/SBER-LSTM-Neural-Network-for-Time-Series-Prediction/master/data/SBER_D1.csv')
df = pd.read_csv(filename, sep=",")
print(df.shape, df.columns)
# Для Финама - df.rename(columns={"<DATE>": "Date", "<TIME>": "Time", "<OPEN>": "Open", "<HIGH>": "High", "<LOW>": "Low","<CLOSE>": "Close", "<VOL>": "Volume"}, inplace=True)
# print(df.shape, df.columns)
# df['Date'] = pd.to_datetime(df['Date'], format='%Y%m%d')
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
# print(df.shape, df.columns)
# df = df.drop('Time', 1)
# Out:
# (5665, 6) Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df
# Out:
#            Date    Open    High     Low   Close      Volume
# 0    1999-06-01    0.54    0.54    0.53    0.53       778.0
# 1    1999-06-02    0.53    0.53    0.49    0.50      1926.0
# 2    1999-06-03    0.49    0.54    0.49    0.53      3346.0
# 3    1999-06-04    0.54    0.55    0.53    0.55      4694.0
# 4    1999-06-07    0.55    0.57    0.55    0.56      3505.0
# ...         ...     ...     ...     ...     ...         ...
# 5660 2022-02-02  265.88  266.91  254.52  261.00  17021508.0
# 5661 2022-02-03  258.45  259.87  250.06  250.79  15116578.0
# 5662 2022-02-04  251.99  259.74  251.91  256.53  12703518.0
# 5663 2022-02-07  256.99  260.53  253.52  257.61   8558821.0
# 5664 2022-02-08  257.60  269.90  256.52  269.80  16152695.0
#
# [5665 rows x 6 columns]

# %%
df["Close"].max(), df["Close"].min()
# Out:
# (387.6, 0.5)

# %%
df_close = df.loc[:, 'Close'] # при желании можно и по объему
close_price = df_close.tolist()
plt.plot(close_price)
plt.show()

# %%
# оставляем последние 3 с хвостом года
df = df[-365*3:]

# %%
df
# Out:
#            Date    Open    High     Low   Close      Volume
# 4570 2017-10-10  194.30  194.45  192.95  193.21   1781678.0
# 4571 2017-10-11  193.94  196.75  193.56  195.83   5793777.0
# 4572 2017-10-12  195.83  196.75  194.95  195.51   3491602.0
# 4573 2017-10-13  195.63  197.29  195.20  196.48   3031997.0
# 4574 2017-10-16  197.53  198.52  196.70  197.70   2689343.0
# ...         ...     ...     ...     ...     ...         ...
# 5660 2022-02-02  265.88  266.91  254.52  261.00  17021508.0
# 5661 2022-02-03  258.45  259.87  250.06  250.79  15116578.0
# 5662 2022-02-04  251.99  259.74  251.91  256.53  12703518.0
# 5663 2022-02-07  256.99  260.53  253.52  257.61   8558821.0
# 5664 2022-02-08  257.60  269.90  256.52  269.80  16152695.0
#
# [1095 rows x 6 columns]

# %%
df_close = df.loc[:, 'Close']
close_price = df_close.tolist()
plt.plot(close_price)
plt.show()

# %%
df["Close"].max(), df["Close"].min()
# Out:
# (387.6, 169.36)

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 4570 to 5664
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1095 non-null   datetime64[ns]
#  1   Open    1095 non-null   float64
#  2   High    1095 non-null   float64
#  3   Low     1095 non-null   float64
#  4   Close   1095 non-null   float64
#  5   Volume  1095 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 51.5 KB
#               Open         High          Low        Close        Volume
# count  1095.000000  1095.000000  1095.000000  1095.000000  1.095000e+03
# mean    243.194283   246.005708   240.125918   243.186831  6.231137e+06
# std      44.322538    44.570660    43.903732    44.276109  4.339256e+06
# min     170.230000   172.670000   165.900000   169.360000  6.450540e+05
# 25%     209.995000   212.290000   207.095000   210.105000  3.745764e+06
# 50%     232.500000   234.730000   229.900000   232.650000  5.153288e+06
# 75%     270.455000   272.960000   266.605000   270.165000  7.404590e+06
# max     385.900000   388.110000   376.720000   387.600000  4.840611e+07

# %%
split = 0.85
i_split = int(len(df)*split)
cols = ["Close", "Volume"] # коррелирующие данные не стоит добавлять, т.к. получается двойное подтверждение
data_train = df.get(cols).values[:i_split]
data_test = df.get(cols).values[i_split:]
len_train = len(data_train)
len_test = len(data_test)
print(len(df), len_train, len_test)
# Out:
# 1095 930 165

# %%
data_train, len_train, data_test, len_test # отладочная информация, просто проверить данные вручную
# Out:
# (array([[1.932100e+02, 1.781678e+06],
#         [1.958300e+02, 5.793777e+06],
#         [1.955100e+02, 3.491602e+06],
#         ...,
#         [3.125100e+02, 2.970489e+06],
#         [3.116100e+02, 3.822496e+06],
#         [3.139000e+02, 4.416454e+06]]),
#  930,
#  array([[3.0930000e+02, 6.2327060e+06],
#         [3.1040000e+02, 3.6086020e+06],
#         [3.0973000e+02, 2.3511320e+06],
#         [3.0979000e+02, 2.4810790e+06],
#         [3.1000000e+02, 1.9708450e+06],
#         [3.1181000e+02, 2.2588790e+06],
#         [3.0948000e+02, 1.9409430e+06],
#         [3.0610000e+02, 3.3868700e+06],
#         [3.0645000e+02, 3.1492940e+06],
#         [3.0578000e+02, 1.9958090e+06],
#         [3.0739000e+02, 2.8893920e+06],
#         [3.0700000e+02, 1.6481560e+06],
#         [3.0334000e+02, 3.2667720e+06],
#         [3.0406000e+02, 2.2612920e+06],
#         [3.0263000e+02, 3.0696840e+06],
#         [3.0356000e+02, 2.0523480e+06],
#         [3.0623000e+02, 2.5280830e+06],
#         [3.0300000e+02, 2.1233230e+06],
#         [3.0150000e+02, 2.3920780e+06],
#         [3.0172000e+02, 2.1082200e+06],
#         [2.9885000e+02, 3.4532240e+06],
#         [2.9146000e+02, 4.1244150e+06],
#         [2.9610000e+02, 3.5564960e+06],
#         [2.9486000e+02, 1.7526680e+06],
#         [2.9727000e+02, 2.0319290e+06],
#         [2.9638000e+02, 1.4959920e+06],
#         [3.0334000e+02, 3.3887060e+06],
#         [2.9971000e+02, 3.8559430e+06],
#         [3.0290000e+02, 2.6896580e+06],
#         [3.0312000e+02, 2.7950010e+06],
#         [3.0559000e+02, 4.9522680e+06],
#         [3.0651000e+02, 3.1506510e+06],
#         [3.0989000e+02, 3.3788860e+06],
#         [3.1110000e+02, 3.0666580e+06],
#         [3.1582000e+02, 3.7290300e+06],
#         [3.1915000e+02, 5.4096400e+06],
#         [3.2691000e+02, 7.1958140e+06],
#         [3.3011000e+02, 4.1507840e+06],
#         [3.2990000e+02, 3.4418000e+06],
#         [3.2857000e+02, 2.0985080e+06],
#         [3.2868000e+02, 1.8758270e+06],
#         [3.2936000e+02, 2.3916510e+06],
#         [3.3450000e+02, 4.2463620e+06],
#         [3.3490000e+02, 3.6270350e+06],
#         [3.3269000e+02, 4.5936410e+06],
#         [3.2567000e+02, 3.6358580e+06],
#         [3.2922000e+02, 2.0584670e+06],
#         [3.2483000e+02, 3.5662860e+06],
#         [3.2457000e+02, 2.8098960e+06],
#         [3.2254000e+02, 2.9404310e+06],
#         [3.2741000e+02, 2.7875240e+06],
#         [3.2828000e+02, 2.0366300e+06],
#         [3.2794000e+02, 3.2466620e+06],
#         [3.3457000e+02, 3.0689260e+06],
#         [3.2900000e+02, 3.1557640e+06],
#         [3.2971000e+02, 2.9610670e+06],
#         [3.2937000e+02, 1.7484870e+06],
#         [3.2596000e+02, 2.4463960e+06],
#         [3.3170000e+02, 4.7863530e+06],
#         [3.2601000e+02, 2.9891820e+06],
#         [3.2625000e+02, 1.7427700e+06],
#         [3.2741000e+02, 2.4368160e+06],
#         [3.2648000e+02, 2.2503730e+06],
#         [3.3351000e+02, 4.3839450e+06],
#         [3.2699000e+02, 6.2479590e+06],
#         [3.2956000e+02, 5.4127200e+06],
#         [3.2692000e+02, 3.2111750e+06],
#         [3.2325000e+02, 4.8989900e+06],
#         [3.2780000e+02, 3.8092830e+06],
#         [3.2702000e+02, 2.7550810e+06],
#         [3.2544000e+02, 2.4603680e+06],
#         [3.3168000e+02, 3.4380790e+06],
#         [3.2930000e+02, 5.2526260e+06],
#         [3.2843000e+02, 2.7623960e+06],
#         [3.4099000e+02, 8.3456110e+06],
#         [3.3848000e+02, 3.7620170e+06],
#         [3.4585000e+02, 6.0753740e+06],
#         [3.6320000e+02, 8.6813850e+06],
#         [3.6428000e+02, 9.5590810e+06],
#         [3.6893000e+02, 4.9526260e+06],
#         [3.7301000e+02, 3.1015850e+06],
#         [3.8760000e+02, 6.6939520e+06],
#         [3.7779000e+02, 5.1421960e+06],
#         [3.7880000e+02, 5.4674590e+06],
#         [3.7609000e+02, 3.6297720e+06],
#         [3.7182000e+02, 3.7299610e+06],
#         [3.6460000e+02, 3.8131280e+06],
#         [3.7318000e+02, 4.0014100e+06],
#         [3.7016000e+02, 2.7520560e+06],
#         [3.6460000e+02, 2.4509930e+06],
#         [3.6437000e+02, 2.6333560e+06],
#         [3.6999000e+02, 3.5641730e+06],
#         [3.7216000e+02, 4.1753420e+06],
#         [3.7136000e+02, 3.6322230e+06],
#         [3.6536000e+02, 5.3831860e+06],
#         [3.5614000e+02, 5.3480230e+06],
#         [3.7096000e+02, 5.5126260e+06],
#         [3.7070000e+02, 3.7715790e+06],
#         [3.7013000e+02, 3.0859550e+06],
#         [3.6021000e+02, 3.9019490e+06],
#         [3.5839000e+02, 3.9674430e+06],
#         [3.5744000e+02, 4.1693520e+06],
#         [3.4865000e+02, 4.6528880e+06],
#         [3.5624000e+02, 4.2866310e+06],
#         [3.4759000e+02, 1.0070476e+07],
#         [3.4439000e+02, 5.9812330e+06],
#         [3.3791000e+02, 6.1961410e+06],
#         [3.3989000e+02, 4.9468730e+06],
#         [3.3693000e+02, 4.7109020e+06],
#         [3.2756000e+02, 6.6920640e+06],
#         [3.0915000e+02, 1.4400629e+07],
#         [3.2684000e+02, 1.4482075e+07],
#         [3.2122000e+02, 7.7871300e+06],
#         [3.1729000e+02, 4.4050430e+06],
#         [3.0442000e+02, 9.0384610e+06],
#         [3.1657000e+02, 8.2196350e+06],
#         [3.1500000e+02, 9.8246810e+06],
#         [3.2440000e+02, 6.9783640e+06],
#         [3.2680000e+02, 6.1409640e+06],
#         [3.2066000e+02, 4.3078530e+06],
#         [3.0750000e+02, 9.9680710e+06],
#         [3.0979000e+02, 1.5414909e+07],
#         [2.9695000e+02, 2.4103057e+07],
#         [3.0040000e+02, 1.3391986e+07],
#         [2.9744000e+02, 8.2036480e+06],
#         [2.8064000e+02, 1.4631293e+07],
#         [2.8490000e+02, 1.8527850e+07],
#         [2.8665000e+02, 8.7523500e+06],
#         [2.9589000e+02, 1.3470559e+07],
#         [2.9490000e+02, 1.0979608e+07],
#         [2.8840000e+02, 7.9696720e+06],
#         [2.9170000e+02, 6.4957570e+06],
#         [2.9400000e+02, 6.5509930e+06],
#         [2.9280000e+02, 5.5542710e+06],
#         [2.9389000e+02, 3.7675550e+06],
#         [2.9568000e+02, 3.6175280e+06],
#         [2.9500000e+02, 3.7849850e+06],
#         [2.9351000e+02, 3.7676200e+06],
#         [2.9349000e+02, 4.2567960e+06],
#         [3.0547000e+02, 5.0183500e+06],
#         [3.0424000e+02, 5.3270420e+06],
#         [2.8701000e+02, 7.0017630e+06],
#         [2.9392000e+02, 7.9382440e+06],
#         [2.9169000e+02, 6.7428670e+06],
#         [2.9188000e+02, 5.8921530e+06],
#         [2.9040000e+02, 8.1822570e+06],
#         [2.7250000e+02, 2.1155619e+07],
#         [2.6100000e+02, 4.0632869e+07],
#         [2.5778000e+02, 2.4868925e+07],
#         [2.3470000e+02, 4.8406108e+07],
#         [2.4486000e+02, 3.6095899e+07],
#         [2.5461000e+02, 3.2911510e+07],
#         [2.4690000e+02, 2.9569067e+07],
#         [2.3697000e+02, 3.2582995e+07],
#         [2.3959000e+02, 2.3259697e+07],
#         [2.3690000e+02, 2.2488086e+07],
#         [2.5429000e+02, 3.0130665e+07],
#         [2.5782000e+02, 2.0418032e+07],
#         [2.6942000e+02, 1.5619224e+07],
#         [2.6470000e+02, 1.7039614e+07],
#         [2.6100000e+02, 1.7021508e+07],
#         [2.5079000e+02, 1.5116578e+07],
#         [2.5653000e+02, 1.2703518e+07],
#         [2.5761000e+02, 8.5588210e+06],
#         [2.6980000e+02, 1.6152695e+07]]),
#  165)

# %%
# формы наших данных
# по цифре 2 видим, что есть объемы и цена закрытия
data_train.shape, data_test.shape
# если вставить 3 столбец, то вторая цифра изменится с 2 на 3
# Out:
# ((930, 2), (165, 2))

# %%
# определяем параметры нашей сети
# sequence_length - сколько мы будем подавать элементов
# длина последовательности = 49 + 1, потому что 50-е прзначение как раз будем пытаться предсказать,
# поэтому размерность входных данных = 2,
sequence_length = 50; input_dim = 2; batch_size = 32; epochs = 5 # изменил кол-во эпох на 5 с 2 в 3-ем видео

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.LSTM(100, input_shape=(sequence_length-1, input_dim), return_sequences=True),
#     tf.keras.layers.Dropout(.2),
#     tf.keras.layers.LSTM(100, return_sequences=True),
#     tf.keras.layers.LSTM(100, return_sequences=False),
#     tf.keras.layers.Dropout(.2),
#     tf.keras.layers.Dense(1, activation='linear')
# ])

# %%
#model = tf.keras.Sequential([
    #tf.keras.layers.LSTM(50, input_shape=(sequence_length-1, input_dim), return_sequences=True),
    #tf.keras.layers.Dropout(.2),
    #tf.keras.layers.LSTM(50, return_sequences=False),
    #tf.keras.layers.Dropout(.2),
    #tf.keras.layers.Dense(1, activation='linear')
#])

# %%
# model.summary()

# %%
# tf.keras.utils.plot_model(model, "multi_input_and_output_model.png", show_shapes=True)

# %%
# # 32:50 - вводятся необходимые метрики, которые помогают отслеживать точность предсказаний, можно без метрик.
# # Но лучше с ними, т.к. можно заканчивать обучение сети, когда метрика дотигает какой-то величины. Этот момент нужно изучать отдельно, и использовать под свою задачу.
# model.compile(optimizer='adam',
#               loss=tf.keras.losses.MeanSquaredError(),
#               metrics=['accuracy'])

# %%
# model.compile(optimizer='adam',
#               loss='mse')

# %%
# model.compile(optimizer='adam',
#               loss='mse',
#               metrics=['accuracy'])

# %%
# Эту нормализацию поменяна во 2 видео
# В видео по нормализации у него несколько методов
# 2 - 55:00 - Я так понял, что выполняется последний блок нормализации, если их несколько
def normalise_windows(window_data, single_window=False):
  '''Normalise window with a base value of zero'''
  normalised_data = []
  window_data = [window_data] if single_window else window_data
  for window in window_data:
    normalised_window = []
    for col_i in range(window.shape[1]):
      max_in_column = max(window[:, col_i])
      min_in_column = min(window[:, col_i])
      normalised_col = [((float(p) - float(min_in_column)) / (float(max_in_column) - float(min_in_column))) for p in window[:, col_i]]
      normalised_window.append(normalised_col)
    normalised_window = np.array(normalised_window).T # reshape and transpose array back into original multidimensional format
    normalised_data.append(normalised_window)
  return np.array(normalised_data)

# %%
def _next_window(i, seq_len, normalise):
  '''Generates the next dara window fron the given index location i'''
  window = data_train[i:i+seq_len]
  window = normalise_windows(window, single_window=True)[0] if normalise else window
  x = window[:-1]
  y = window[-1, [0]]
  return x, y

# %%
# функция тренировочных данных
def get_train_data(seq_len, normalise):
        '''
        Create x, y train data windows
        Warning: batch method, not generative, make sure you have enough memory to
        load data, otherwise use generate_training_window() method.
        '''
        data_x = []
        data_y = []
        for i in range(len_train - seq_len + 1):
            x, y = _next_window(i, seq_len, normalise)
            data_x.append(x)
            data_y.append(y)
        return np.array(data_x), np.array(data_y)

# %%
# загружаем их в эти 2 переменные x_train, y_train
x_train, y_train = get_train_data(
    seq_len=sequence_length,
    normalise=True
    # Если False, то нормализация не будет применяться
)

# %%
# выводим на экран их формы, чтобы посмотреть
# почему-то значение 49 на выходе, показало ему что у нас вывод уже с батчами
print(x_train.shape, y_train.shape[0])
# Out:
# (881, 49, 2) 881

# %%
# это просто отладочная информация вывода этого массива, чтьобы посмотреть, что всё ОК
for i in range(x_train.shape[0]):
  print(x_train[i])
  break
# Out:
# [[0.0300308  0.        ]
#  [0.09727926 0.31927388]
#  [0.08906571 0.13607193]
#  [0.11396304 0.09949759]
#  [0.14527721 0.07222995]
#  [0.13244353 0.06673304]
#  [0.08393224 0.20461202]
#  [0.00410678 0.17892655]
#  [0.02387064 0.08692749]
#  [0.00770021 0.07247219]
#  [0.01180698 0.08295354]
#  [0.         0.1148031 ]
#  [0.01822382 0.06201257]
#  [0.10292608 0.2299355 ]
#  [0.07597536 0.11214497]
#  [0.04517454 0.06192607]
#  [0.05159138 0.1783212 ]
#  [0.04645791 0.12636846]
#  [0.04517454 0.10166664]
#  [0.35728953 0.9323959 ]
#  [0.43762834 0.56044011]
#  [0.71894251 0.78619587]
#  [0.65862423 1.        ]
#  [0.63064682 0.26339063]
#  [0.75359343 0.22319646]
#  [0.87037988 0.43235961]
#  [0.91016427 0.54111895]
#  [0.86267967 0.15993237]
#  [0.83572895 0.00802566]
#  [1.         0.47515049]
#  [0.98074949 0.2235018 ]
#  [0.86036961 0.18555339]
#  [0.92299795 0.21031115]
#  [0.89117043 0.04900638]
#  [0.97433265 0.17649696]
#  [0.92813142 0.13138433]
#  [0.82931211 0.22511333]
#  [0.75616016 0.17608793]
#  [0.83572895 0.2166858 ]
#  [0.81801848 0.07996237]
#  [0.8139117  0.04203592]
#  [0.71278234 0.16224848]
#  [0.74050308 0.08348488]
#  [0.91504107 0.13285922]
#  [0.92043121 0.1731617 ]
#  [0.76386037 0.34812496]
#  [0.97176591 0.30060326]
#  [0.88526694 0.19621219]
#  [0.90759754 0.05329538]]

# %%
prices = x_train[0][:,0] # взять данные по колонке 0
prices
# Out:
# array([0.0300308 , 0.09727926, 0.08906571, 0.11396304, 0.14527721,
#        0.13244353, 0.08393224, 0.00410678, 0.02387064, 0.00770021,
#        0.01180698, 0.        , 0.01822382, 0.10292608, 0.07597536,
#        0.04517454, 0.05159138, 0.04645791, 0.04517454, 0.35728953,
#        0.43762834, 0.71894251, 0.65862423, 0.63064682, 0.75359343,
#        0.87037988, 0.91016427, 0.86267967, 0.83572895, 1.        ,
#        0.98074949, 0.86036961, 0.92299795, 0.89117043, 0.97433265,
#        0.92813142, 0.82931211, 0.75616016, 0.83572895, 0.81801848,
#        0.8139117 , 0.71278234, 0.74050308, 0.91504107, 0.92043121,
#        0.76386037, 0.97176591, 0.88526694, 0.90759754])

# %%
max(prices), min(prices)
# Out:
# (1.0, 0.0)

# %%
volumes = x_train[0][:,1] # взять данные по колонке 1
volumes
# Out:
# array([0.        , 0.31927388, 0.13607193, 0.09949759, 0.07222995,
#        0.06673304, 0.20461202, 0.17892655, 0.08692749, 0.07247219,
#        0.08295354, 0.1148031 , 0.06201257, 0.2299355 , 0.11214497,
#        0.06192607, 0.1783212 , 0.12636846, 0.10166664, 0.9323959 ,
#        0.56044011, 0.78619587, 1.        , 0.26339063, 0.22319646,
#        0.43235961, 0.54111895, 0.15993237, 0.00802566, 0.47515049,
#        0.2235018 , 0.18555339, 0.21031115, 0.04900638, 0.17649696,
#        0.13138433, 0.22511333, 0.17608793, 0.2166858 , 0.07996237,
#        0.04203592, 0.16224848, 0.08348488, 0.13285922, 0.1731617 ,
#        0.34812496, 0.30060326, 0.19621219, 0.05329538])

# %%
max(volumes), min(volumes)
# Out:
# (1.0, 0.0)

# %%
print(x_train, y_train, x_train.shape, y_train.shape)
# Out:
# [[[0.0300308  0.        ]
#   [0.09727926 0.31927388]
#   [0.08906571 0.13607193]
#   ...
#   [0.97176591 0.30060326]
#   [0.88526694 0.19621219]
#   [0.90759754 0.05329538]]
#
#  [[0.09727926 0.3137664 ]
#   [0.08906571 0.12908225]
#   [0.11396304 0.092212  ]
#   ...
#   [0.88526694 0.18970908]
#   [0.90759754 0.04563598]
#   [0.82289528 0.12954593]]
#
#  [[0.08906571 0.12908225]
#   [0.11396304 0.092212  ]
#   [0.14527721 0.06472375]
#   ...
#   [0.90759754 0.04563598]
#   [0.82289528 0.12954593]
#   [0.87166324 0.12291272]]
#
#  ...
#
#  [[0.01099182 0.84715273]
#   [0.0743865  0.79519322]
#   [0.07208589 0.44584914]
#   ...
#   [0.85761759 0.11122511]
#   [0.81620654 0.        ]
#   [0.8448364  0.05474544]]
#
#  [[0.0743865  0.79519322]
#   [0.07208589 0.44584914]
#   [0.         0.27604779]
#   ...
#   [0.81620654 0.        ]
#   [0.8448364  0.05474544]
#   [0.80368098 0.11889766]]
#
#  [[0.07208589 0.44584914]
#   [0.         0.27604779]
#   [0.01738241 0.53513404]
#   ...
#   [0.8448364  0.05474544]
#   [0.80368098 0.11889766]
#   [0.78067485 0.24872513]]] [[0.82289528]
#  [0.87166324]
#  [0.8100616 ]
#  [0.75462012]
#  [0.8023614 ]
#  [0.80929158]
#  [0.89681725]
#  [0.82546201]
#  [0.85112936]
#  [1.        ]
#  [1.        ]
#  [0.99572284]
#  [1.        ]
#  [0.94334764]
#  [0.96995708]
#  [0.94313305]
#  [0.9667382 ]
#  [0.98369099]
#  [0.98755365]
#  [1.        ]
#  [0.9162318 ]
#  [0.94773278]
#  [0.96192454]
#  [1.        ]
#  [1.        ]
#  [0.88193318]
#  [0.99481025]
#  [1.        ]
#  [1.        ]
#  [0.97091072]
#  [0.83933766]
#  [0.80174536]
#  [0.87558738]
#  [0.84515552]
#  [0.74692325]
#  [0.67800403]
#  [0.7885433 ]
#  [0.8612665 ]
#  [0.94473036]
#  [1.        ]
#  [1.        ]
#  [0.99703264]
#  [1.        ]
#  [1.        ]
#  [0.97039474]
#  [1.        ]
#  [0.96992995]
#  [0.87066462]
#  [0.91508628]
#  [0.88091577]
#  [0.94925679]
#  [0.89851358]
#  [0.89800103]
#  [0.90524087]
#  [0.89946809]
#  [0.89205666]
#  [0.68674915]
#  [0.53514698]
#  [0.50447264]
#  [0.40857414]
#  [0.45949787]
#  [0.73732828]
#  [0.65727144]
#  [0.57437234]
#  [0.40857414]
#  [0.46571012]
#  [0.29407389]
#  [0.32577833]
#  [0.29637527]
#  [0.20095949]
#  [0.21150639]
#  [0.31740231]
#  [0.45495905]
#  [0.29602669]
#  [0.        ]
#  [0.03703151]
#  [0.        ]
#  [0.0584966 ]
#  [0.        ]
#  [0.        ]
#  [0.17563417]
#  [0.27084518]
#  [0.24331703]
#  [0.26504379]
#  [0.35479468]
#  [0.35195086]
#  [0.32294392]
#  [0.32578774]
#  [0.36230235]
#  [0.37242635]
#  [0.39733819]
#  [0.42042999]
#  [0.40916847]
#  [0.41508361]
#  [0.42998521]
#  [0.40208938]
#  [0.4902284 ]
#  [0.51400989]
#  [0.53849776]
#  [0.46303273]
#  [0.45723286]
#  [0.41180034]
#  [0.36515629]
#  [0.41524805]
#  [0.40957382]
#  [0.37672481]
#  [0.38987243]
#  [0.36370737]
#  [0.37542307]
#  [0.35068992]
#  [0.37685499]
#  [0.4125817 ]
#  [0.39948527]
#  [0.39948527]
#  [0.33600229]
#  [0.36945954]
#  [0.34815556]
#  [0.27008865]
#  [0.2936803 ]
#  [0.26150987]
#  [0.32799542]
#  [0.31369745]
#  [0.26738794]
#  [0.31132488]
#  [0.30476607]
#  [0.44031482]
#  [0.40096196]
#  [0.48906865]
#  [0.22846524]
#  [0.        ]
#  [0.21219319]
#  [0.22670889]
#  [0.47743468]
#  [0.55687516]
#  [0.48931116]
#  [0.46951702]
#  [0.65003959]
#  [0.70731064]
#  [0.79414093]
#  [0.80205859]
#  [0.73000792]
#  [0.7044075 ]
#  [0.79018211]
#  [0.74109264]
#  [0.59619952]
#  [0.43204012]
#  [0.20031671]
#  [0.11691739]
#  [0.27033037]
#  [0.51135242]
#  [0.45376769]
#  [0.33201711]
#  [0.29582099]
#  [0.37578151]
#  [0.49193814]
#  [0.35176045]
#  [0.2201382 ]
#  [0.07568279]
#  [0.13129319]
#  [0.06186245]
#  [0.        ]
#  [0.07277628]
#  [0.        ]
#  [0.08720272]
#  [0.14971687]
#  [0.0414496 ]
#  [0.12344281]
#  [0.07701019]
#  [0.11438279]
#  [0.12797282]
#  [0.03737259]
#  [0.        ]
#  [0.03256445]
#  [0.08838922]
#  [0.06377205]
#  [0.09284745]
#  [0.        ]
#  [0.07648184]
#  [0.06137667]
#  [0.02868069]
#  [0.00879541]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.07449951]
#  [0.23203151]
#  [0.31752543]
#  [0.30767968]
#  [0.36849066]
#  [0.40568689]
#  [0.36039015]
#  [0.41071124]
#  [0.55306737]
#  [0.55818414]
#  [0.57344326]
#  [0.75374268]
#  [0.73681927]
#  [0.75591235]
#  [0.66241758]
#  [0.63604396]
#  [0.43934066]
#  [0.39208791]
#  [0.49428571]
#  [0.53079534]
#  [0.55128894]
#  [0.45665901]
#  [0.64552239]
#  [0.61882893]
#  [0.76607348]
#  [0.7086682 ]
#  [0.62112514]
#  [0.41446613]
#  [0.32548794]
#  [0.33409874]
#  [0.53530425]
#  [0.49799082]
#  [0.33409874]
#  [0.46584386]
#  [0.44259472]
#  [0.58668197]
#  [0.55424799]
#  [0.66704937]
#  [0.8163031 ]
#  [0.93398393]
#  [0.96239954]
#  [0.75746269]
#  [0.78817451]
#  [0.78071183]
#  [0.8564868 ]
#  [0.88375431]
#  [0.85820896]
#  [0.8217566 ]
#  [0.71326062]
#  [0.77887789]
#  [0.79574468]
#  [0.70638298]
#  [0.33191489]
#  [0.43957447]
#  [0.40425532]
#  [0.64085106]
#  [0.56595745]
#  [0.83404255]
#  [0.7787234 ]
#  [0.65106383]
#  [0.48893617]
#  [0.60893617]
#  [0.47234043]
#  [0.53492564]
#  [0.43938711]
#  [0.38170347]
#  [0.19062641]
#  [0.07210455]
#  [0.26588553]
#  [0.36728256]
#  [0.38756196]
#  [0.27444795]
#  [0.16223524]
#  [0.1171699 ]
#  [0.12167643]
#  [0.19378098]
#  [0.261379  ]
#  [0.25236593]
#  [0.27364093]
#  [0.45637277]
#  [0.46779351]
#  [0.73092736]
#  [0.70179699]
#  [0.70422535]
#  [0.70422535]
#  [0.76250607]
#  [0.92083536]
#  [1.        ]
#  [1.        ]
#  [0.95141546]
#  [0.98125478]
#  [1.        ]
#  [1.        ]
#  [0.99331104]
#  [0.91638796]
#  [1.        ]
#  [0.98498882]
#  [1.        ]
#  [0.95477528]
#  [0.93258427]
#  [0.99859551]
#  [0.96320225]
#  [0.80646067]
#  [0.79016854]
#  [0.89044944]
#  [1.        ]
#  [0.85869565]
#  [0.6013587 ]
#  [0.69836957]
#  [0.59483696]
#  [0.5375    ]
#  [0.66820652]
#  [0.5736413 ]
#  [0.6236413 ]
#  [0.64021739]
#  [0.63858696]
#  [0.62771739]
#  [0.68435754]
#  [0.64916201]
#  [0.62011173]
#  [0.54804469]
#  [0.60614525]
#  [0.57681564]
#  [0.61204482]
#  [0.58944282]
#  [0.60060976]
#  [0.52926829]
#  [0.51572719]
#  [0.53041622]
#  [0.5908112 ]
#  [0.58389262]
#  [0.62013423]
#  [0.48878924]
#  [0.77130045]
#  [0.9478673 ]
#  [0.71973094]
#  [0.76321974]
#  [0.72502938]
#  [0.91774383]
#  [0.94888367]
#  [0.99706228]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.88413462]
#  [0.89951923]
#  [0.85865385]
#  [0.74903846]
#  [0.77451923]
#  [0.73822115]
#  [0.73365385]
#  [0.80120192]
#  [0.80745192]
#  [0.81538462]
#  [0.61826923]
#  [0.50721154]
#  [0.64230769]
#  [0.55504808]
#  [0.64229637]
#  [0.72620216]
#  [0.73307164]
#  [0.70093229]
#  [0.66437684]
#  [0.59077527]
#  [0.52257115]
#  [0.61236506]
#  [0.63223749]
#  [0.61997056]
#  [0.58285572]
#  [0.55943185]
#  [0.72663843]
#  [0.80513332]
#  [0.64166459]
#  [0.76999751]
#  [0.80862198]
#  [0.72233986]
#  [0.71428571]
#  [0.69622012]
#  [0.7098388 ]
#  [0.8963313 ]
#  [0.74123989]
#  [0.84178499]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.58115016]
#  [0.72343191]
#  [0.65943239]
#  [0.58823529]
#  [0.7211464 ]
#  [0.66692486]
#  [0.81022463]
#  [0.57474826]
#  [0.616189  ]
#  [0.5236251 ]
#  [0.6742835 ]
#  [0.67079783]
#  [0.59527498]
#  [0.76684741]
#  [0.6979086 ]
#  [0.70991479]
#  [0.76065066]
#  [0.76103796]
#  [0.7792409 ]
#  [0.75755229]
#  [0.78853914]
#  [0.68926554]
#  [0.5165456 ]
#  [0.44592413]
#  [0.42493947]
#  [0.42009685]
#  [0.42615012]
#  [0.34826473]
#  [0.24737692]
#  [0.28173913]
#  [0.20217391]
#  [0.3       ]
#  [0.19782609]
#  [0.29565217]
#  [0.34010152]
#  [0.21269036]
#  [0.01015228]
#  [0.        ]
#  [0.05072721]
#  [0.18446258]
#  [0.05108194]
#  [0.11067755]
#  [0.        ]
#  [0.05753618]
#  [0.08859866]
#  [0.        ]
#  [0.        ]
#  [0.01336821]
#  [0.08166231]
#  [0.04778041]
#  [0.13656388]
#  [0.16638428]
#  [0.16638428]
#  [0.13249746]
#  [0.1118265 ]
#  [0.12572009]
#  [0.23688721]
#  [0.32944806]
#  [0.41446692]
#  [0.3225917 ]
#  [0.42886527]
#  [0.5553651 ]
#  [0.49468632]
#  [0.49400069]
#  [0.64141241]
#  [0.69009256]
#  [0.68495029]
#  [0.63112787]
#  [0.71066164]
#  [0.73020226]
#  [0.77536503]
#  [0.90905038]
#  [0.81317142]
#  [0.70574498]
#  [0.60298926]
#  [0.63054647]
#  [0.67725362]
#  [0.62867819]
#  [0.61279776]
#  [0.55581504]
#  [0.41616067]
#  [0.44325082]
#  [0.38159738]
#  [0.60532461]
#  [0.5370892 ]
#  [0.61549296]
#  [0.65305164]
#  [0.73802817]
#  [0.64835681]
#  [0.69530516]
#  [0.77042254]
#  [0.88779343]
#  [0.98403756]
#  [0.95539906]
#  [1.        ]
#  [0.99205719]
#  [1.        ]
#  [0.89619119]
#  [0.78528753]
#  [0.892728  ]
#  [0.86862194]
#  [0.68300522]
#  [0.74367216]
#  [0.82924869]
#  [0.84640523]
#  [0.98684211]
#  [0.86963037]
#  [0.93606394]
#  [0.85464535]
#  [0.72177822]
#  [0.73626374]
#  [0.86113886]
#  [0.73376623]
#  [0.82367632]
#  [0.75024975]
#  [0.71878122]
#  [0.76773227]
#  [0.76023976]
#  [0.61138861]
#  [0.57242757]
#  [0.62137862]
#  [0.56043956]
#  [0.54995005]
#  [0.39460539]
#  [0.44105894]
#  [0.44705295]
#  [0.61838162]
#  [0.71328671]
#  [0.75674326]
#  [0.87712288]
#  [0.91358641]
#  [0.92157842]
#  [0.92059701]
#  [0.92955224]
#  [1.        ]
#  [0.87640449]
#  [0.91629213]
#  [1.        ]
#  [0.99329897]
#  [0.95810364]
#  [0.969129  ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9548069 ]
#  [1.        ]
#  [0.95928396]
#  [0.96630397]
#  [1.        ]
#  [0.89445495]
#  [0.80812854]
#  [0.84593573]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.95935829]
#  [0.8842246 ]
#  [0.93128342]
#  [0.65935829]
#  [0.72299465]
#  [0.7828877 ]
#  [0.71256684]
#  [0.57593583]
#  [0.62379679]
#  [0.66149733]
#  [0.65614973]
#  [0.57352941]
#  [0.63208556]
#  [0.57754011]
#  [0.63743316]
#  [0.63743316]
#  [0.62112299]
#  [0.56390374]
#  [0.54208939]
#  [0.48115543]
#  [0.44228433]
#  [0.42263056]
#  [0.42752902]
#  [0.17555876]
#  [0.36097742]
#  [0.06219739]
#  [0.        ]
#  [0.        ]
#  [0.21208323]
#  [0.17798947]
#  [0.10428679]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.24622897]
#  [0.21638633]
#  [0.08790016]
#  [0.        ]
#  [0.16249067]
#  [0.22838256]
#  [0.09702527]
#  [0.1958631 ]
#  [0.14724384]
#  [0.14713722]
#  [0.06514554]
#  [0.09308029]
#  [0.1379678 ]
#  [0.11205885]
#  [0.13742278]
#  [0.12464372]
#  [0.18011401]
#  [0.27267422]
#  [0.30372359]
#  [0.34247695]
#  [0.33381503]
#  [0.29569826]
#  [0.28472821]
#  [0.14544558]
#  [0.17583097]
#  [0.21849682]
#  [0.18758569]
#  [0.14682787]
#  [0.19855416]
#  [0.20777764]
#  [0.1838734 ]
#  [0.18882292]
#  [0.2403684 ]
#  [0.28132758]
#  [0.3002744 ]
#  [0.2537567 ]
#  [0.26760747]
#  [0.28002091]
#  [0.27753822]
#  [0.31700918]
#  [0.27469532]
#  [0.2091084 ]
#  [0.15298268]
#  [0.15704918]
#  [0.25249742]
#  [0.32217848]
#  [0.67177914]
#  [0.61792774]
#  [0.49863667]
#  [0.57021132]
#  [0.6724608 ]
#  [0.82617587]
#  [1.        ]
#  [0.81722177]
#  [0.94557271]
#  [1.        ]
#  [1.        ]
#  [0.79571984]
#  [0.94163424]
#  [0.97081712]
#  [0.88909091]
#  [0.76200584]
#  [0.65110109]
#  [0.62377288]
#  [0.63544707]
#  [0.64552932]
#  [0.52958344]
#  [0.61528257]
#  [0.59936323]
#  [0.62324224]
#  [0.61315999]
#  [0.51313346]
#  [0.58344388]
#  [0.51499071]
#  [0.68426638]
#  [0.7200849 ]
#  [0.81719289]
#  [0.70894136]
#  [0.72061555]
#  [0.67126559]
#  [0.75537278]
#  [0.65216238]
#  [0.68161316]
#  [0.72379942]
#  [0.7306978 ]
#  [0.71637039]
#  [0.79808968]
#  [0.84690899]
#  [0.87291059]
#  [0.83841868]
#  [0.85327673]
#  [0.87795171]
#  [0.84143426]
#  [0.92883436]
#  [0.89723926]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9789823 ]
#  [0.96501809]
#  [1.        ]
#  [0.95182972]
#  [1.        ]
#  [1.        ]
#  [0.97426752]
#  [0.93859873]
#  [0.88280255]
#  [0.84458599]
#  [0.92356688]
#  [0.74726115]
#  [0.71515924]
#  [0.73019108]
#  [0.63515924]
#  [0.62802548]
#  [0.58802548]
#  [0.58980892]
#  [0.58471338]
#  [0.62394904]
#  [0.49477707]
#  [0.38649682]
#  [0.4856051 ]
#  [0.46197039]
#  [0.36906585]
#  [0.28256395]
#  [0.35901206]
#  [0.37283152]
#  [0.55807116]
#  [0.67950603]
#  [0.66656866]
#  [0.6783299 ]
#  [0.64422229]
#  [0.50911854]
#  [0.60367205]
#  [0.55998734]
#  [0.54954099]
#  [0.50333216]
#  [0.48981104]
#  [0.37310115]
#  [0.50870693]
#  [0.43542985]
#  [0.        ]
#  [0.00267857]
#  [0.07083333]
#  [0.05357143]
#  [0.        ]
#  [0.        ]
#  [0.02160994]
#  [0.        ]
#  [0.07492641]
#  [0.        ]
#  [0.        ]
#  [0.03904924]
#  [0.20300752]
#  [0.22774739]
#  [0.23286965]
#  [0.34867905]
#  [0.25974366]
#  [0.16923882]
#  [0.11370169]
#  [0.1439295 ]
#  [0.        ]
#  [0.11504425]
#  [0.2690921 ]
#  [0.51491314]
#  [0.54113405]
#  [0.88692232]
#  [1.        ]
#  [1.        ]
#  [0.95093728]
#  [0.97199722]
#  [1.        ]
#  [0.9512766 ]
#  [0.88765957]
#  [0.83574468]
#  [0.81765957]
#  [0.82361702]
#  [0.98595745]
#  [1.        ]
#  [0.96445405]
#  [0.99371563]
#  [0.95522388]
#  [1.        ]
#  [1.        ]
#  [0.98541303]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.95431472]
#  [0.93920715]
#  [0.93497704]
#  [0.93678994]
#  [0.83599226]
#  [0.734832  ]
#  [0.73785352]
#  [0.8352671 ]
#  [0.82583998]
#  [0.84179357]
#  [0.89086294]
#  [0.8582306 ]
#  [0.85400048]
#  [0.8582306 ]
#  [0.89690597]
#  [0.86947063]
#  [0.99891226]
#  [1.        ]
#  [1.        ]
#  [0.93022472]
#  [0.93917417]
#  [0.837975  ]
#  [0.86082685]
#  [0.83721893]
#  [0.83548595]
#  [0.710707  ]
#  [0.57010085]
#  [0.51176587]
#  [0.59165513]
#  [0.51572078]
#  [0.52481709]
#  [0.36958671]
#  [0.48210401]
#  [0.46925054]
#  [0.47385166]
#  [0.53398969]
#  [0.54682854]
#  [0.63354807]
#  [0.47943508]
#  [0.4031219 ]
#  [0.20671267]
#  [0.24749059]
#  [0.42973651]
#  [0.40119197]
#  [0.40119197]
#  [0.27854454]
#  [0.41499373]
#  [0.38895859]
#  [0.48933501]
#  [0.4325596 ]
#  [0.39523212]
#  [0.3782936 ]
#  [0.48525721]
#  [0.65840652]
#  [0.62421581]
#  [0.52195734]
#  [0.60821832]
#  [0.86825596]
#  [0.75690088]
#  [0.87484316]
#  [0.8412798 ]
#  [1.        ]
#  [0.98816055]
#  [0.72884782]
#  [0.61045336]
#  [0.79006642]
#  [0.88189431]
#  [0.7071903 ]
#  [0.79930696]
#  [0.82442969]
#  [0.95610742]
#  [1.        ]
#  [0.99857914]
#  [0.93520887]
#  [0.91304348]
#  [0.95453254]
#  [0.87155442]
#  [0.66467747]
#  [0.73515203]
#  [0.73259449]
#  [0.65245808]
#  [0.61691542]
#  [0.8225539 ]
#  [0.79442392]
#  [0.66503497]
#  [0.83216783]
#  [0.8048951 ]
#  [0.79440559]
#  [0.85839161]
#  [0.96083916]
#  [0.9959707 ]
#  [1.        ]
#  [1.        ]
#  [0.99968264]
#  [0.95556966]
#  [0.97282033]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.72044626]
#  [0.60013204]
#  [0.70400528]
#  [0.64590669]
#  [0.61934879]
#  [0.64802149]
#  [0.43356131]
#  [0.42672203]
#  [0.53688324]
#  [0.52393747]
#  [0.672936  ]
#  [0.67806546]
#  [0.81753786]
#  [0.72827198]
#  [0.7597137 ]
#  [0.78041922]
#  [0.84125767]
#  [0.80112474]
#  [0.76354806]
#  [0.88087935]
#  [0.86298569]
#  [0.86170757]
#  [0.85761759]
#  [0.81620654]
#  [0.8448364 ]
#  [0.80368098]
#  [0.78067485]
#  [0.83921268]] (881, 49, 2) (881, 1)

# %%
# 3 - 26:00 - Еще одна функция тренировочного набора, которая создана немножко по-другому,
# данные те же самые формируются, но Шпанину она кажется немного удобнее
def get_train_data2(seq_len, normalise):
        '''
        Create x, y test data windows
        Warning: batch method, not generative, make sure you have enough memory to
        load data, otherwise reduce size of the training split.
        '''
        data_windows = []
        for i in range(len_train - seq_len + 1):
            data_windows.append(data_train[i:i+seq_len])

        data_windows = np.array(data_windows).astype(float)
        data_windows = normalise_windows(data_windows, single_window=False) if normalise else data_windows # False, потому что тренировочный набор

        x = data_windows[:, :-1]
        y = data_windows[:, -1, [0]]
        return x,y

# %%
x_train2, y_train2 = get_train_data2(
    seq_len=sequence_length,
    normalise=True
)

# %%
print("train data shapes: ", x_train.shape, y_train.shape)
print("train data shapes: ", x_train2.shape, y_train2.shape)
# Out:
# train data shapes:  (881, 49, 2) (881, 1)
# train data shapes:  (881, 49, 2) (881, 1)

# %%
# генерируем тестовый набор данных
def get_test_data(seq_len, normalise):
        '''
        Create x, y test data windows
        Warning: batch method, not generative, make sure you have enough memory to
        load data, otherwise reduce size of the training split.
        '''
        data_windows = []
        for i in range(len_test - seq_len):
            data_windows.append(data_test[i:i+seq_len])

        data_windows = np.array(data_windows).astype(float)
        data_windows = normalise_windows(data_windows, single_window=False) if normalise else data_windows # False, потому что тренировочный набор

        x = data_windows[:, :-1]
        y = data_windows[:, -1, [0]]
        return x,y

# %%
# тестовые данные сохраняем в эти 2 объекта
x_test, y_test = get_test_data(
    seq_len=sequence_length,
    normalise=True
)

# %%
print("test data shapes: ", x_test.shape, y_test.shape)
#print(x_test, y_test, x_test.shape, y_test.shape)
# Out:
# test data shapes:  (115, 49, 2) (115, 1)

# %%
import math

# out-of memory generative training
steps_per_epoch  = math.ceil((len_train - sequence_length) / batch_size)
print(steps_per_epoch)
# Out:
# 28

# %%
batch_size = 32

# %%
# 3 - 27:30 - эта модель из англоязычного файла, она черновая, тестовая. Возможно Шпагин ее поменяет
# 3 - 28:30 - Модель Sequential неэффективна, нужна модель, которая будет иметь несколько разных входов, где параллельные модели будут соединяться,
# чтобы учитывать не только цены, но и другие показатели
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(100, input_shape=(sequence_length-1, input_dim), return_sequences=True),
    tf.keras.layers.Dropout(.2),
    tf.keras.layers.LSTM(100, return_sequences=True),
    tf.keras.layers.LSTM(100, return_sequences=False),
    tf.keras.layers.Dropout(.2),
    tf.keras.layers.Dense(1, activation='linear')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 49, 100)           41200
#
#  dropout (Dropout)           (None, 49, 100)           0
#
#  lstm_1 (LSTM)               (None, 49, 100)           80400
#
#  lstm_2 (LSTM)               (None, 100)               80400
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 202101 (789.46 KB)
# Trainable params: 202101 (789.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='mse',
              metrics=[tf.keras.metrics.MeanSquaredError()])
# большинство статей указывают что оптимизатор adam самый лучший
# 3 - 29:30 - adam часто взрывается, кьы prop стабильнее (из комментариев)

# %%
callbacks = [
    tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
]
# Здесь с помощью log_dir (куда сохраняются логи при обучении нейросети), можно построить график потерь или отображения точности сети

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.LSTM(100, input_shape=(sequence_length-1, input_dim), return_sequences=True),
#     tf.keras.layers.Dropout(.2),
#     tf.keras.layers.LSTM(100, return_sequences=True),
#     tf.keras.layers.LSTM(100, return_sequences=False),
#     tf.keras.layers.Dropout(.2),
#     tf.keras.layers.Dense(1, activation='linear')
# ])
# model.compile(optimizer='adam',
#               loss='mse',
#               metrics=[tf.keras.metrics.MeanSquaredError()])
# callbacks = [
#     tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
# ]

# %%
# # underfit
# history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, callbacks=callbacks)

# %%
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('model train vs validation loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'validation'], loc='upper right')
# plt.show()

# %%
# та же самая модель. Мы ее заново сбрасываем, потому что она уже обучена.
# Если ее не сбросить, то мы будем обучать модель 2-ой раз, и ее веса будут заново перестраиваться
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(100, input_shape=(sequence_length-1, input_dim), return_sequences=True),
    tf.keras.layers.Dropout(.2),
    tf.keras.layers.LSTM(100, return_sequences=True),
    tf.keras.layers.LSTM(100, return_sequences=False),
    tf.keras.layers.Dropout(.2),
    tf.keras.layers.Dense(1, activation='linear')
])
model.compile(optimizer='adam',
              loss='mse',
              metrics=[tf.keras.metrics.MeanSquaredError()])
callbacks = [
    tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
]

# %%
# goodfit
# больше кол-во эпох. Это уже гуд, но не когда мы уже выходим по метрикам
history = model.fit(x_train, y_train, epochs=200, batch_size=batch_size, validation_split=0.2, callbacks=callbacks)
# Out:
# Epoch 1/200
# 22/22 [==============================] - 10s 169ms/step - loss: 0.1063 - mean_squared_error: 0.1063 - val_loss: 0.0827 - val_mean_squared_error: 0.0827
# Epoch 2/200
# 22/22 [==============================] - 2s 114ms/step - loss: 0.0552 - mean_squared_error: 0.0552 - val_loss: 0.0522 - val_mean_squared_error: 0.0522
# Epoch 3/200
# 22/22 [==============================] - 2s 114ms/step - loss: 0.0444 - mean_squared_error: 0.0444 - val_loss: 0.0422 - val_mean_squared_error: 0.0422
# Epoch 4/200
# 22/22 [==============================] - 3s 138ms/step - loss: 0.0404 - mean_squared_error: 0.0404 - val_loss: 0.0383 - val_mean_squared_error: 0.0383
# Epoch 5/200
# 22/22 [==============================] - 3s 123ms/step - loss: 0.0341 - mean_squared_error: 0.0341 - val_loss: 0.0375 - val_mean_squared_error: 0.0375
# Epoch 6/200
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0302 - mean_squared_error: 0.0302 - val_loss: 0.0365 - val_mean_squared_error: 0.0365
# Epoch 7/200
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.0322 - val_mean_squared_error: 0.0322
# Epoch 8/200
# 22/22 [==============================] - 3s 116ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0297 - val_mean_squared_error: 0.0297
# Epoch 9/200
# 22/22 [==============================] - 3s 159ms/step - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 10/200
# 22/22 [==============================] - 2s 114ms/step - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0299 - val_mean_squared_error: 0.0299
# Epoch 11/200
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 12/200
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0226 - val_mean_squared_error: 0.0226
# Epoch 13/200
# 22/22 [==============================] - 3s 116ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 14/200
# 22/22 [==============================] - 3s 157ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 15/200
# 22/22 [==============================] - 3s 120ms/step - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 16/200
# 22/22 [==============================] - 3s 115ms/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 17/200
# 22/22 [==============================] - 3s 120ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 18/200
# 22/22 [==============================] - 3s 140ms/step - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 19/200
# 22/22 [==============================] - 3s 117ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 20/200
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 21/200
# 22/22 [==============================] - 3s 118ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 22/200
# 22/22 [==============================] - 2s 113ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 23/200
# 22/22 [==============================] - 3s 149ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 24/200
# 22/22 [==============================] - 3s 121ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 25/200
# 22/22 [==============================] - 3s 116ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 26/200
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0134 - val_mean_squared_error: 0.0134
# Epoch 27/200
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0130 - val_mean_squared_error: 0.0130
# Epoch 28/200
# 22/22 [==============================] - 4s 162ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 29/200
# 22/22 [==============================] - 2s 114ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0123 - val_mean_squared_error: 0.0123
# Epoch 30/200
# 22/22 [==============================] - 3s 123ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 31/200
# 22/22 [==============================] - 3s 115ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 32/200
# 22/22 [==============================] - 3s 144ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 33/200
# 22/22 [==============================] - 3s 131ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0134 - val_mean_squared_error: 0.0134
# Epoch 34/200
# 22/22 [==============================] - 3s 115ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 35/200
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0130 - val_mean_squared_error: 0.0130
# Epoch 36/200
# 22/22 [==============================] - 3s 117ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 37/200
# 22/22 [==============================] - 3s 155ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 38/200
# 22/22 [==============================] - 3s 120ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 39/200
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 40/200
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 41/200
# 22/22 [==============================] - 2s 113ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 42/200
# 22/22 [==============================] - 3s 145ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 43/200
# 22/22 [==============================] - 2s 113ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 44/200
# 22/22 [==============================] - 3s 118ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 45/200
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 46/200
# 22/22 [==============================] - 3s 130ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 47/200
# 22/22 [==============================] - 3s 136ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 48/200
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 49/200
# 22/22 [==============================] - 3s 119ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 50/200
# 22/22 [==============================] - 3s 119ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 51/200
# 22/22 [==============================] - 3s 153ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 52/200
# 22/22 [==============================] - 3s 124ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 53/200
# 22/22 [==============================] - 3s 119ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 54/200
# 22/22 [==============================] - 3s 116ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 55/200
# 22/22 [==============================] - 3s 129ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 56/200
# 22/22 [==============================] - 3s 130ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 57/200
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 58/200
# 22/22 [==============================] - 3s 121ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 59/200
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 60/200
# 22/22 [==============================] - 3s 157ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 61/200
# 22/22 [==============================] - 3s 114ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 62/200
# 22/22 [==============================] - 2s 112ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 63/200
# 22/22 [==============================] - 3s 116ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 64/200
# 22/22 [==============================] - 3s 117ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# Epoch 65/200
# 22/22 [==============================] - 3s 152ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 66/200
# 22/22 [==============================] - 2s 112ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 67/200
# 22/22 [==============================] - 3s 118ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 68/200
# 22/22 [==============================] - 3s 119ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 69/200
# 22/22 [==============================] - 3s 145ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 70/200
# 22/22 [==============================] - 3s 124ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 71/200
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 72/200
# 22/22 [==============================] - 2s 113ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 73/200
# 22/22 [==============================] - 3s 121ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 74/200
# 22/22 [==============================] - 3s 162ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 75/200
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 76/200
# 22/22 [==============================] - 3s 115ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 77/200
# 22/22 [==============================] - 2s 114ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 78/200
# 22/22 [==============================] - 3s 127ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 79/200
# 22/22 [==============================] - 3s 132ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0102 - val_mean_squared_error: 0.0102
# Epoch 80/200
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 81/200
# 22/22 [==============================] - 3s 121ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 82/200
# 22/22 [==============================] - 3s 120ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 83/200
# 22/22 [==============================] - 3s 151ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 84/200
#  1/22 [>.............................] - ETA: 2s - loss: 0.0178 - mean_squared_error: 0.0178
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-32284161832b> in <cell line: 3>()
#       1 # goodfit
#       2 # больше кол-во эпох. Это уже гуд, но не когда мы уже выходим по метрикам
# ----> 3 history = model.fit(x_train, y_train, epochs=200, batch_size=batch_size, validation_split=0.2, callbacks=callbacks)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# получается глаже, но можно еще глаже если поработать с нормализацией и моделью
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
from keras.callbacks import EarlyStopping
callbacks = [
    EarlyStopping(monitor='val_loss', patience=2)
    ]

# %%
callbacks = [
    EarlyStopping(monitor='accuracy', patience=2)
]

# %%
model.fit(x,y, epochs=epochs, batch_size=batch_size, callbacks=callbacks)
# ЕСТЬ ВИДЕО НА КАНАЛЕ КАК КОНЕКТИТЬСЯ К МЕТАТРЕЙДЕРУ, ТАК ЖЕ МОЖНО И К КВИКУ

# %%
# model.fit(x,y, epochs=epochs)
# он закомментил, потому что то же самое, что и перед этим

# %%
# генерируем тестовый набор даных
def get_test_data(seq_len, normalise):
        '''
        Create x, y test data windows
        Warning: batch method, not generative, make sure you have enough memory to
        load data, otherwise reduce size of the training split.
        '''
        data_windows = []
        for i in range(len_test - seq_len):
            data_windows.append(data_test[i:i+seq_len])

        data_windows = np.array(data_windows).astype(float)
        data_windows = normalise_windows(data_windows, single_window=False) if normalise else data_windows # False, потому что тренировочный набор

        x = data_windows[:, :-1]
        y = data_windows[:, -1, [0]]
        return x,y

# %%
x_test, y_test = get_test_data(
    seq_len=sequence_length,
    normalise=True
)

# %%
print("test data shapes: ", x_test.shape, y_test.shape)
#print(x_test, y_test, x_test.shape, y_test.shape)

# %%
model.evaluate(x_test, y_test, verbose=2)

# %%
def get_last_data(seq_len, normalise):
  # 2 - 32:00 - это последние данные из загруженного нами csv файла. Правда по его мнению это не совсем верно брать такой data_test
  last_data = data_test[seq_len:]
  data_windows = np.array(last_data).astype(float)
   #data_windows = np.array([data_windows])
   #data_windows = self.normalise_windows(data_windows, single_window=False) if normalise else data_windows
  data_windows = normalise_windows(data_windows, single_window=True) if normalise else data_windows # True , потому что мы передаем data_windows для предсказания без объемов, поэтому это одно окошко (2 - 1:17:56 + 1:19:30)
  return data_windows

# %%
last_data_2_predict_prices = get_last_data(-(sequence_length-1), False)

# last_data_2_predict_prices_1st_price = last_data_2_predict_prices [0][0]
# last_data_2_predict = get_last_data(-(sequence_length-1), True)
# # Если последнюю нормализацию поставить на False, то мы увидим последние данные из csv таблицы
# print("*** ", -(sequence_length-1 ), last_data_2_predict.size, "***")

# %%
last_data_2_predict_prices # не нормализованные цены

# %%
last_data_2_predict_prices = get_last_data(-(sequence_length-1), False)
last_data_2_predict_prices_1st_price = last_data_2_predict_prices[0][0]
last_data_2_predict_prices_max = max(last_data_2_predict_prices[:,0])
last_data_2_predict_prices_min = min(last_data_2_predict_prices[:,0])

last_data_2_predict_prices_1st_price, last_data_2_predict_prices_max, last_data_2_predict_prices_min
# last_data_2_predict_prices_1st_price - столько стоил Сбер 49 дней назад, это первый элемент в последней последовательности. По сути для данного типа нормализации не нужно. Нужны минимум и максимум

# %%
last_data_2_predict = get_last_data(-(sequence_length-1), True) # теперь передаем сюда с нормализацией
# Если последнюю нормализацию поставить на False, то мы увидим последние данные из csv таблицы
print("*** ", -(sequence_length-1 ), last_data_2_predict.size, "***")

# %%
last_data_2_predict # нормализованные цены
# 50:00 - Самая большая ошибка: обрубить свечной график и учитывать только цены закрытия
# 51:00 - В начале в cols перечислить другое кол-во элементов и нейросеть сформируется под новые параметры.
# При этом нужно изменить input_dim
# !!!Нормализация объемов не сработала!!! 59:00 - Возможно сильно объем поменялся и нормализация не сработала
# 1:02:30 - Рассказывает что нужно сделать

# %%
last_data_2_predict_prices # теперь эти данные можно послать в нейросеть, чтобы спрогнозировать следующую свечу (2 - 1:18:30)

# %%
# запрашиваем нормализацию максимума и минимума

# %%
predictions2 = model.predict(last_data_2_predict)
print(predictions2, predictions2 [0][0])
# простое предсказание

# %%
#денормализация
def de_normalise_predicted(price_max, price_min, _data):
  return (_data*(price_max - price_min) + price_min)

# %%
predicted_price = de_normalise_predicted(last_data_2_predict_prices_max, last_data_2_predict_prices_min, predictions2[0][0])
predicted_price
